# %% [markdown]
# ### Importando modulos

# %%
from tools import IBGETools

# %% [markdown]
# ### Acessando o objeto IBGE

# %%
objIBGE = IBGETools.getIBGE()

# %% [markdown]
# ### Extrair dados do SIDRA

# %%
#Raspando informacoes do SIDRA
dataFrame = objIBGE.scrapingdata(1612)

#Visualizando a informacao do SIDRA
dataFrame
# Out:
#       Nível Territorial (Código)     Nível Territorial Ano (Código)   Ano  \
# 1                              3  Unidade da Federação         2017  2017
# 2                              3  Unidade da Federação         2017  2017
# 3                              3  Unidade da Federação         2017  2017
# 4                              3  Unidade da Federação         2017  2017
# 5                              3  Unidade da Federação         2017  2017
# ...                          ...                   ...          ...   ...
# 84044                          6             Município         2017  2017
# 84045                          6             Município         2017  2017
# 84046                          6             Município         2017  2017
# 84047                          6             Município         2017  2017
# 84048                          6             Município         2017  2017
#
#       Variável (Código)                                       Variável  \
# ...

# %% [markdown]
# ### Salvando a tabela

# %%
objIBGE.saveData(dataframe=dataFrame,arquivoSaida='<endereco de saida>')
